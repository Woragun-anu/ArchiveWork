# %% [markdown]
# # Lab 8: Sorting

# %% [markdown]
# Instructor: Sirasit Lochanachit
#
# Course: 01526102 Data Sturctures and Algorithms

# %% [markdown]
# ## Gentle reminder of Big-O of sorting operations
#
# - Bubble Sort: $O(N^2)$
# - Selection Sort: $O(N^2)$
# - Insertion Sort: $O(N^2)$
# - Merge Sort: $O(N log_2 N)$

# %% [markdown]
# ## Lab 8-1: Implement Bubble, Selection, and Insertion Sort in ascending order (lower numbers to higher numbers)

# %% [markdown]
# ### 8.1.1 Write a bubbleSort on an input list
# - Print round number for each round
# - Print current list after each round has finished
# - Print number of comparisons and exchanges after the last round has finished

# %%
def bubbleSort(alist): #HR
    print("Original list: ", alist, "\n")
    no_compare = 0
    no_exchange = 0
    n = len(alist)
    for i in range(n-1):
      print("Round: ",str(i+1))
      print("Current List: ",alist)
      for j in range(n-i-1):
        if alist[j] > alist[j+1]:
          no_exchange+=1
          alist[j],alist[j+1] = alist[j+1], alist[j]
        no_compare +=1

    print("Number of Comparisons: ", no_compare)
    print("Number of Exchanges: ", no_exchange)

# %%
inputList = [54,26,93,17,77,31,44,55,20]
bubbleSort(inputList)
print(inputList)
# Out:
# Original list:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
#
# Round:  1
# Current List:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Round:  2
# Current List:  [26, 54, 17, 77, 31, 44, 55, 20, 93]
# Round:  3
# Current List:  [26, 17, 54, 31, 44, 55, 20, 77, 93]
# Round:  4
# Current List:  [17, 26, 31, 44, 54, 20, 55, 77, 93]
# Round:  5
# Current List:  [17, 26, 31, 44, 20, 54, 55, 77, 93]
# Round:  6
# Current List:  [17, 26, 31, 20, 44, 54, 55, 77, 93]
# Round:  7
# Current List:  [17, 26, 20, 31, 44, 54, 55, 77, 93]
# Round:  8
# Current List:  [17, 20, 26, 31, 44, 54, 55, 77, 93]
# Number of Comparisons:  36
# Number of Exchanges:  20
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
inputList = [12, 90, 53, 63, 76, 1, 38, 42]
bubbleSort(inputList)
print(inputList)
# Out:
# Original list:  [12, 90, 53, 63, 76, 1, 38, 42]
#
# Round:  1
# Current List:  [12, 90, 53, 63, 76, 1, 38, 42]
# Round:  2
# Current List:  [12, 53, 63, 76, 1, 38, 42, 90]
# Round:  3
# Current List:  [12, 53, 63, 1, 38, 42, 76, 90]
# Round:  4
# Current List:  [12, 53, 1, 38, 42, 63, 76, 90]
# Round:  5
# Current List:  [12, 1, 38, 42, 53, 63, 76, 90]
# Round:  6
# Current List:  [1, 12, 38, 42, 53, 63, 76, 90]
# Round:  7
# Current List:  [1, 12, 38, 42, 53, 63, 76, 90]
# Number of Comparisons:  28
# Number of Exchanges:  16
# [1, 12, 38, 42, 53, 63, 76, 90]

# %% [markdown]
# ### 8.1.2 Write a selectionSort on an input list
# - Print round number for each round
# - Print a position to insert the selected item in sorted area
# - Print a position of the selected item from the unsorted area
# - Print current list after each round has finished
# - Print number of comparisons and exchanges after the last round has finished

# %%
def selectionSort(alist):
    print("Original list: ", alist, "\n")
    no_compare = 0
    no_exchange = 0
    n = len(alist)
    for i in range(n):
        min_idx = i
        print(f"Round {i + 1}:")
        print("Current list:", alist)

        for j in range(i + 1, len(alist)):
            no_compare += 1
            if alist[j] < alist[min_idx]:
                min_idx = j

        print(f"Position to insert : {i}")
        print(f"Position of min item : {min_idx}")
        if min_idx != i:
            alist[i], alist[min_idx] = alist[min_idx], alist[i]
            no_exchange += 1

    print("Number of Comparisons:", no_compare)
    print("Number of Exchanges:", no_exchange)

# %%
inputList = [54,26,93,17,77,31,44,55,20]
selectionSort(inputList)
print(inputList)
# Out:
# Original list:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
#
# Round 1:
# Current list: [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Position to insert : 0
# Position of min item : 3
# Round 2:
# Current list: [17, 26, 93, 54, 77, 31, 44, 55, 20]
# Position to insert : 1
# Position of min item : 8
# Round 3:
# Current list: [17, 20, 93, 54, 77, 31, 44, 55, 26]
# Position to insert : 2
# Position of min item : 8
# Round 4:
# Current list: [17, 20, 26, 54, 77, 31, 44, 55, 93]
# Position to insert : 3
# Position of min item : 5
# Round 5:
# Current list: [17, 20, 26, 31, 77, 54, 44, 55, 93]
# Position to insert : 4
# Position of min item : 6
# Round 6:
# Current list: [17, 20, 26, 31, 44, 54, 77, 55, 93]
# Position to insert : 5
# Position of min item : 5
# Round 7:
# Current list: [17, 20, 26, 31, 44, 54, 77, 55, 93]
# Position to insert : 6
# Position of min item : 7
# Round 8:
# Current list: [17, 20, 26, 31, 44, 54, 55, 77, 93]
# Position to insert : 7
# Position of min item : 7
# Round 9:
# Current list: [17, 20, 26, 31, 44, 54, 55, 77, 93]
# Position to insert : 8
# Position of min item : 8
# Number of Comparisons: 36
# Number of Exchanges: 6
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
inputList = [12, 90, 53, 63, 76, 1, 38, 42]
selectionSort(inputList)
print(inputList)
# Out:
# Original list:  [12, 90, 53, 63, 76, 1, 38, 42]
#
# Round 1:
# Current list: [12, 90, 53, 63, 76, 1, 38, 42]
# Position to insert : 0
# Position of min item : 5
# Round 2:
# Current list: [1, 90, 53, 63, 76, 12, 38, 42]
# Position to insert : 1
# Position of min item : 5
# Round 3:
# Current list: [1, 12, 53, 63, 76, 90, 38, 42]
# Position to insert : 2
# Position of min item : 6
# Round 4:
# Current list: [1, 12, 38, 63, 76, 90, 53, 42]
# Position to insert : 3
# Position of min item : 7
# Round 5:
# Current list: [1, 12, 38, 42, 76, 90, 53, 63]
# Position to insert : 4
# Position of min item : 6
# Round 6:
# Current list: [1, 12, 38, 42, 53, 90, 76, 63]
# Position to insert : 5
# Position of min item : 7
# Round 7:
# Current list: [1, 12, 38, 42, 53, 63, 76, 90]
# Position to insert : 6
# Position of min item : 6
# Round 8:
# Current list: [1, 12, 38, 42, 53, 63, 76, 90]
# Position to insert : 7
# Position of min item : 7
# Number of Comparisons: 28
# Number of Exchanges: 6
# [1, 12, 38, 42, 53, 63, 76, 90]

# %% [markdown]
# ### 8.1.3 Write a insertionSort on an input list
# - Print round number for each round
# - Print a current selected/drew value in an unsorted area
# - Print a position of the current selected/drew value in an unsorted area
# - Print a position of the inserted item into the sorted area
# - Print current list after each round has finished
# - Print number of comparisons and exchanges after the last round has finished

# %%
def insertionSort(alist):
    print("Original list: ", alist, "\n")
    no_compare = 0
    no_exchange = 0
    n = len(alist)
    for i in range(1, n):
      key = alist[i] #26
      j = i-1 #0
      print(f"round {i}")
      print(f"Current Value {key}")
      print(f"Position of Current value {i}")
      while j >= 0 and key < alist[j]:
          no_compare +=1
          alist[j+1] = alist[j]
          j -= 1
          no_exchange +=1
      alist[j+1] = key
      print(f"position to insert {j+1}")
      print("Current List", alist)


    print("Number of Comparisons: ", no_compare)
    print("Number of Exchanges: ", no_exchange)

# %%
inputList = [54,26,93,17,77,31,44,55,20]
insertionSort(inputList)
print(inputList)
# Out:
# Original list:  [54, 26, 93, 17, 77, 31, 44, 55, 20]
#
# round 1
# Current Value 26
# Position of Current value 1
# position to insert 0
# Current List [26, 54, 93, 17, 77, 31, 44, 55, 20]
# round 2
# Current Value 93
# Position of Current value 2
# position to insert 2
# Current List [26, 54, 93, 17, 77, 31, 44, 55, 20]
# round 3
# Current Value 17
# Position of Current value 3
# position to insert 0
# Current List [17, 26, 54, 93, 77, 31, 44, 55, 20]
# round 4
# Current Value 77
# Position of Current value 4
# position to insert 3
# Current List [17, 26, 54, 77, 93, 31, 44, 55, 20]
# round 5
# Current Value 31
# Position of Current value 5
# position to insert 2
# Current List [17, 26, 31, 54, 77, 93, 44, 55, 20]
# round 6
# Current Value 44
# Position of Current value 6
# position to insert 3
# Current List [17, 26, 31, 44, 54, 77, 93, 55, 20]
# round 7
# Current Value 55
# Position of Current value 7
# position to insert 5
# Current List [17, 26, 31, 44, 54, 55, 77, 93, 20]
# round 8
# Current Value 20
# Position of Current value 8
# position to insert 1
# Current List [17, 20, 26, 31, 44, 54, 55, 77, 93]
# Number of Comparisons:  20
# Number of Exchanges:  20
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
inputList = [12, 90, 53, 63, 76, 1, 38, 42]
insertionSort(inputList)
print(inputList)
# Out:
# Original list:  [12, 90, 53, 63, 76, 1, 38, 42]
#
# Number of Comparisons:  16
# Number of Exchanges:  16
# [1, 12, 38, 42, 53, 63, 76, 90]

# %% [markdown]
# ## Lab 8-2: Sorting Playing Cards

# %% [markdown]
# ### Modify bubbleSort, SelectionSort, and insertSort function to sort a deck of cards
#
# - Sort by numbers from lower numbers to higher numbers ('A' is the lowest number)
# - If two cards have the same number, sort them by suit as follows: clubs (♣) < diamonds (♦) < hearts (♥) < spades (♠)

# %%
def cardValue(card):
  cv = ""
  sign = "♣♦♥♠"
  for i in card:
    if i == 'A':
      i = '0'
    elif i in sign:
      i = sign.index(i)
    cv+=str(i)
  if len(card)>2:
    cv = 'A'  + cv[2]
  return cv

print('4♣'>'4♠') #A♣ ->00 #10 -> A A,B,.. <J 10<J<Q<K / 3 -> 10 -> JQK A-> Y 2 ->Z
# Out:
# True

# %%
def bubbleSort_card(alist):
    print("Original list: ", alist, "\n")
    no_compare = 0
    no_exchange = 0
    for i in range(len(alist) - 1):
        swapped = False
        print(f"Round {i + 1}:")
        print("Current list:", alist)

        for j in range(len(alist) - i - 1):
            no_compare += 1
            card1 = cardValue(alist[j])
            card2 = cardValue(alist[j + 1])
            if card1 > card2 :
                alist[j], alist[j + 1] = alist[j+1] , alist[j]
                no_exchange += 1
                swapped = True

        if not swapped:
            break

        print("Current list after this round:", alist, "\n")


    print("Number of Comparisons: ", no_compare)
    print("Number of Exchanges: ", no_exchange)

# %%
inputList = ['4♣','A♣','10♥','K♦','4♠','10♣','3♦','7♥','4♦']
bubbleSort_card(inputList)
print(inputList)
# Out:
# Original list:  ['4♣', 'A♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
#
# Round 1:
# Current list: ['4♣', 'A♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
# Current list after this round: ['A♣', '4♣', '10♥', '4♠', '10♣', '3♦', '7♥', '4♦', 'K♦']
#
# Round 2:
# Current list: ['A♣', '4♣', '10♥', '4♠', '10♣', '3♦', '7♥', '4♦', 'K♦']
# Current list after this round: ['A♣', '4♣', '4♠', '10♣', '3♦', '7♥', '4♦', '10♥', 'K♦']
#
# Round 3:
# Current list: ['A♣', '4♣', '4♠', '10♣', '3♦', '7♥', '4♦', '10♥', 'K♦']
# Current list after this round: ['A♣', '4♣', '4♠', '3♦', '7♥', '4♦', '10♣', '10♥', 'K♦']
#
# Round 4:
# Current list: ['A♣', '4♣', '4♠', '3♦', '7♥', '4♦', '10♣', '10♥', 'K♦']
# Current list after this round: ['A♣', '4♣', '3♦', '4♠', '4♦', '7♥', '10♣', '10♥', 'K♦']
#
# Round 5:
# Current list: ['A♣', '4♣', '3♦', '4♠', '4♦', '7♥', '10♣', '10♥', 'K♦']
# Current list after this round: ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']
#
# Round 6:
# Current list: ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']
# Number of Comparisons:  33
# Number of Exchanges:  18
# ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']

# %%
def selectionSort_card(alist):
    print("Original list: ", alist, "\n")
    no_compare = 0
    no_exchange = 0
    n = len(alist)
    for i in range(n):
        min_idx = i
        print(f"Round {i + 1}:")
        print("Current list:", alist)

        for j in range(i + 1, len(alist)):
            no_compare += 1
            if cardValue(alist[j]) < cardValue(alist[min_idx]):
                min_idx = j

        print(f"Position to insert : {i}")
        print(f"Position of min item : {min_idx}")
        if min_idx != i:
            alist[i], alist[min_idx] = alist[min_idx], alist[i]
            no_exchange += 1

    print("Number of Comparisons: ", no_compare)
    print("Number of Exchanges: ", no_exchange)

# %%
inputList = ['4♣','A♣','10♥','K♦','4♠','10♣','3♦','7♥','4♦']
selectionSort_card(inputList)
print(inputList)
# Out:
# Original list:  ['4♣', 'A♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
#
# Round 1:
# Current list: ['4♣', 'A♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
# Position to insert : 0
# Position of min item : 1
# Round 2:
# Current list: ['A♣', '4♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
# Position to insert : 1
# Position of min item : 6
# Round 3:
# Current list: ['A♣', '3♦', '10♥', 'K♦', '4♠', '10♣', '4♣', '7♥', '4♦']
# Position to insert : 2
# Position of min item : 6
# Round 4:
# Current list: ['A♣', '3♦', '4♣', 'K♦', '4♠', '10♣', '10♥', '7♥', '4♦']
# Position to insert : 3
# Position of min item : 8
# Round 5:
# Current list: ['A♣', '3♦', '4♣', '4♦', '4♠', '10♣', '10♥', '7♥', 'K♦']
# Position to insert : 4
# Position of min item : 4
# Round 6:
# Current list: ['A♣', '3♦', '4♣', '4♦', '4♠', '10♣', '10♥', '7♥', 'K♦']
# Position to insert : 5
# Position of min item : 7
# Round 7:
# Current list: ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♥', '10♣', 'K♦']
# Position to insert : 6
# Position of min item : 7
# Round 8:
# Current list: ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']
# Position to insert : 7
# Position of min item : 7
# Round 9:
# Current list: ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']
# Position to insert : 8
# Position of min item : 8
# Number of Comparisons:  36
# Number of Exchanges:  6
# ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']

# %%
def insertionSort_card(alist):
    print("Original list: ", alist, "\n")
    no_compare = 0
    no_exchange = 0
    n = len(alist)
    for i in range(1, n):
      key = alist[i]
      j = i-1
      print(f"\nround {i}")
      print(f"Current Value {key}")
      print(f"Position of Current Value {i}")
      while j >= 0 and cardValue(key) < cardValue(alist[j]):
          no_compare +=1
          alist[j+1] = alist[j]
          j -= 1
          no_exchange +=1
      print(f"Position to Insert {j+1}")
      alist[j+1] = key
      print("Current List", alist)


    print("\nNumber of Comparisons: ", no_compare)
    print("Number of Exchanges: ", no_exchange)

# %%
inputList = ['4♣','A♣','10♥','K♦','4♠','10♣','3♦','7♥','4♦']
insertionSort_card(inputList)
print(inputList)
# Out:
# Original list:  ['4♣', 'A♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
#
#
# round 1
# Current Value A♣
# Position of Current Value 1
# Position to Insert 0
# Current List ['A♣', '4♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
#
# round 2
# Current Value 10♥
# Position of Current Value 2
# Position to Insert 2
# Current List ['A♣', '4♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
#
# round 3
# Current Value K♦
# Position of Current Value 3
# Position to Insert 3
# Current List ['A♣', '4♣', '10♥', 'K♦', '4♠', '10♣', '3♦', '7♥', '4♦']
#
# round 4
# Current Value 4♠
# Position of Current Value 4
# Position to Insert 2
# Current List ['A♣', '4♣', '4♠', '10♥', 'K♦', '10♣', '3♦', '7♥', '4♦']
#
# round 5
# Current Value 10♣
# Position of Current Value 5
# Position to Insert 3
# Current List ['A♣', '4♣', '4♠', '10♣', '10♥', 'K♦', '3♦', '7♥', '4♦']
#
# round 6
# Current Value 3♦
# Position of Current Value 6
# Position to Insert 1
# Current List ['A♣', '3♦', '4♣', '4♠', '10♣', '10♥', 'K♦', '7♥', '4♦']
#
# round 7
# Current Value 7♥
# Position of Current Value 7
# Position to Insert 4
# Current List ['A♣', '3♦', '4♣', '4♠', '7♥', '10♣', '10♥', 'K♦', '4♦']
#
# round 8
# Current Value 4♦
# Position of Current Value 8
# Position to Insert 3
# Current List ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']
#
# Number of Comparisons:  18
# Number of Exchanges:  18
# ['A♣', '3♦', '4♣', '4♦', '4♠', '7♥', '10♣', '10♥', 'K♦']
