# %% [markdown]
# # Sentence-based entity sentiment analysis
#
# This exercise asks you to create a simple sentence-based entity sentiment analysis where you require to
#
# * split each sentence from the text.
# * only select a sentence that contains targeted entities ["PERSON", "ORG", "PRODUCT"] based on the "Name entity recognition" technique.
# * apply sentiment analysis model on sentences containing targeted entity.
#
# Show an output for only sentences containing targeted entities :
# - Name of the entity, sentiment polarity, split sentence

# %%
# !pip install spacy
# !pip install spacytextblob
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.5/636.5 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.17.1
#     Uninstalling textblob-0.17.1:
#       Successfully uninstalled textblob-0.17.1
# ...

# %%
from spacytextblob.spacytextblob import SpacyTextBlob
import spacy
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
targeted_entity = ["PERSON","ORG","PRODUCT"]

text = "Facebook just had its worst day ever on Wall Street.\
Through all of the challenges Facebook has faced over the years, one thing has been constant: More and more people have kept signing up and logging on.\
But that changed in the last three months of 2021, when the world\'s biggest social network lost daily users for the first time ever.\
On Thursday, Facebook\'s parent company Meta had had its worst day ever on Wall Street, as disillusioned investors sliced its market value by 26% — or more than $250 billion."
